# %% [markdown]
# # Getting Started
#
# In this course, you will create a graph database of movies from a set of CSV files.
#
# <img
#     src="https://graphacademy.neo4j.com/courses/importing-cypher/1-importing-data/1-getting-started/images/data-model.svg"
#     alt="Data Model"
#     style="width: 50%; height: auto; display: block; margin: 0 auto;"
# />
#
# ## Source data
#
# When you import data into Neo4j, you typically start with a set of source files.
#
# You may have exported this source data from:
#
# - Relational databases
#
# - Web APIs
#
# - Public data directories
#
# - BI tools
#
# - Speadsheets (e.g. Excel or Google Sheets)
#
# The data in the source files may not be in the format needed for your graph data model:
#
# - The source files could contain more data than you need.
#
# - There may not be a 1-1 mapping of the data in a CSV file to a node or relationship.
#
# - The data types might not map directly onto those supported in Neo4j.
#
# Likely, you will need to transform the data before or during the import.
#
# ## Create a graph
#
# Before you start the import process, you should:
#
# 1. Understand the data in the source CSV files.
#
# 2. Inspect and clean (if necessary) the data in the source data files.
#
# 3. Understand the graph data model you will be implementing during the import.
#
# Before you import data into Neo4j, there is no data structure, only the database itself - as you import data, you create the graph data model.
#
# Once you have the source data and a graph data model, you can create the graph by importing the data.
#
# Before you import data into Neo4j, there is no data structure, only the database itself - as you import data, you create the graph data model.
#
# Once you have the source data and a graph data model, you can create the graph by importing the data.
#
# The import involves creating Cypher code to:
#
# - Read the source data.
#
# - Transform the data as needed.
#
# - Create nodes, relationships, and properties to create the graph.
#
# Creating an import process will likely require multiple iterations as you build, test, and refactor.

# %% [markdown]
# # CSV files
#
# ## Normalized Data
#
# **Definition:** Data is organized to minimize redundancy by separating it into multiple related tables (in relational databases) or nodes (in graph databases).
#
# **Characteristics:**
# - Minimizes data duplication
# - Reduces update anomalies (insert, update, delete)
# - Maintains data integrity through relationships
# - Requires joins/relationships to reconstruct complete information
#
# ```cypher
# # Normalized Tables
# CUSTOMERS (customer_id, name, email)
# ORDERS (order_id, customer_id, order_date)
# ORDER_ITEMS (order_id, product_id, quantity)
# PRODUCTS (product_id, name, price)
# ```
#
# Example in Graph Database (Normalized):
#
# ```cypher
# (customer:Customer {id: 1, name: "John"})-[:PLACED]->(order:Order {id: 101, date: "2023-11-08"})
# (order)-[:CONTAINS]->(product:Product {id: 1001, name: "Laptop", price: 999})
# ```
#
# ## Denormalized Data
#
# **Definition:** Data is stored with some redundancy to optimize read performance, often by duplicating data across multiple records.
#
# **Characteristics:**
#
# - Improves read performance by reducing joins
# - Increases storage requirements
# - Can lead to update anomalies if not managed carefully
# - Simplifies queries by keeping related data together
#
# Example in Document Database:
#
# ```json
# {
#   "order_id": 101,
#   "customer": {
#     "name": "John",
#     "email": "john@example.com"
#   },
#   "items": [
#     {
#       "product_name": "Laptop",
#       "price": 999,
#       "quantity": 1
#     }
#   ]
# }
# ```
#
# Example in Graph Database (Denormalized):
#
# ```cypher
# // Some properties duplicated for faster access
# (order:Order {
#   id: 101,
#   date: "2023-11-08",
#   customer_name: "John",  // Denormalized from Customer
#   total: 999
# })-[:CONTAINS]->(product:Product {id: 1001, name: "Laptop"})
# ```

# %% [markdown]
# # Loading CSV files
#
# use the [LOAD CSV](https://neo4j.com/docs/cypher-manual/current/clauses/load-csv/?_gl=1*s1xfuf*_gcl_au*MjEzNTI4NjkxNy4xNzU3MjU4NDMzLjc4MDQ1OTczLjE3NTg0MTY3NjUuMTc1ODQxNjc2NA..*_ga*MTkzMzgxNTk1LjE3NTcyNTg0MzQ.*_ga_DL38Q8KGQC*czE3NjI2MDk2NDYkbzMxJGcxJHQxNzYyNjExMjczJGozJGwwJGgw*_ga_DZP8Z65KK4*czE3NjI2MDk2NDYkbzMxJGcxJHQxNzYyNjExMjczJGozJGwwJGgw) Cypher clause
#
# ```cypher
# LOAD CSV [WITH HEADERS] FROM url [AS alias] [FIELDTERMINATOR char]
# ```
#
# You are going to load a [CSV file that contains people data](https://data.neo4j.com/importing-cypher/people.csv?_gl=1*qxkz4i*_gcl_au*MjEzNTI4NjkxNy4xNzU3MjU4NDMzLjc4MDQ1OTczLjE3NTg0MTY3NjUuMTc1ODQxNjc2NA..*_ga*MTkzMzgxNTk1LjE3NTcyNTg0MzQ.*_ga_DL38Q8KGQC*czE3NjI2MDk2NDYkbzMxJGcxJHQxNzYyNjExMjczJGozJGwwJGgw*_ga_DZP8Z65KK4*czE3NjI2MDk2NDYkbzMxJGcxJHQxNzYyNjExMjczJGozJGwwJGgw):

# %%
import pandas as pd

df = pd.read_csv('https://data.neo4j.com/importing-cypher/people.csv')
df.head()
# Out:
#    personId            name  birthYear
# 0     23945    Gerard Pires       1942
# 1    553509     Helen Reddy       1941
# 2    113934  Susan Flannery       1939

# %%
import os

from dotenv import load_dotenv

load_dotenv()

from neo4j import GraphDatabase

neo4j_uri = os.getenv("NEO4J_URI")
neo4j_user = os.getenv("NEO4J_USERNAME")
neo4j_pass = os.getenv("NEO4J_PASSWORD")
neo4j_db = os.getenv("NEO4J_DATABASE")

neo4j_driver = GraphDatabase.driver(neo4j_uri,
                                   auth=(neo4j_user,neo4j_pass))

# %%
import textwrap
from utils import execute_query

# %%
cypher = textwrap.dedent("""
LOAD CSV WITH HEADERS
FROM 'https://data.neo4j.com/importing-cypher/people.csv'
as row
RETURN row
""")

# %%
res = execute_query(neo4j_driver, cypher)

res
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~/Works/graph-exp/.venv/lib/python3.12/site-packages/neo4j/_sync/io/_bolt_socket.py:167, in BoltSocket._handshake_read(self, ctx, n)
#     166 try:
# --> 167     response = self.recv(n)
#     168     ctx.full_response.extend(response)
#
# File ~/Works/graph-exp/.venv/lib/python3.12/site-packages/neo4j/_async_compat/network/_bolt_socket.py:361, in BoltSocketBase.recv(self, n)
#     360 def recv(self, n):
# --> 361     return self._wait_for_io(self._socket.recv, n)
#
# File ~/Works/graph-exp/.venv/lib/python3.12/site-packages/neo4j/_async_compat/network/_bolt_socket.py:339, in BoltSocketBase._wait_for_io(self, func, *args, **kwargs)
#     338 if self._deadline is None:
# --> 339     return func(*args, **kwargs)
#     340 timeout = self._socket.gettimeout()
#
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# File ~/Works/graph-exp/.venv/lib/python3.12/site-packages/neo4j/_sync/io/_bolt_socket.py:331, in BoltSocket.connect(cls, address, tcp_timeout, deadline, custom_resolver, ssl_context, keep_alive)
#     328 s = cls._connect_secure(
#     329     resolved_address, tcp_timeout, keep_alive, ssl_context
#     330 )
# --> 331 agreed_version, handshake, response = s._handshake(
#     332     resolved_address, deadline
#     333 )
#     334 return s, agreed_version, handshake, response
#
# File ~/Works/graph-exp/.venv/lib/python3.12/site-packages/neo4j/_sync/io/_bolt_socket.py:262, in BoltSocket._handshake(self, resolved_address, deadline)
#     261 ctx.ctx = "four byte Bolt handshake response"
# --> 262 response = self._handshake_read(ctx, 4)
#     264 if response == b"HTTP":
#
# File ~/Works/graph-exp/.venv/lib/python3.12/site-packages/neo4j/_sync/io/_bolt_socket.py:170, in BoltSocket._handshake_read(self, ctx, n)
#     169 except OSError as exc:
# --> 170     raise ServiceUnavailable(
#     171         f"Failed to read {ctx.ctx} from server "
#     172         f"{ctx.resolved_address!r} (deadline {ctx.deadline})"
#     173     ) from exc
#     174 finally:
#
# ServiceUnavailable: Failed to read four byte Bolt handshake response from server ResolvedIPv4Address(('127.0.0.1', 7687)) (deadline Deadline(timeout=60.0))
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 res = execute_query(neo4j_driver, cypher)
#       3 res
#
# File ~/Works/graph-exp/01_import-data/utils.py:6, in execute_query(driver, query, parameters)
#       4 def execute_query(driver: Driver, query: str, parameters: dict = None):
#       5     with driver.session() as session:
# ----> 6         result = session.run(query, parameters)
#       7         return result
#
# File ~/Works/graph-exp/.venv/lib/python3.12/site-packages/neo4j/_sync/work/session.py:315, in Session.run(self, query, parameters, **kwargs)
#     312     self._auto_result._buffer_all()
#     314 if not self._connection:
# --> 315     self._connect(self._config.default_access_mode)
#     316     assert self._connection is not None
#     317 cx = self._connection
#
# File ~/Works/graph-exp/.venv/lib/python3.12/site-packages/neo4j/_sync/work/session.py:136, in Session._connect(self, access_mode, **acquire_kwargs)
#     134     access_mode = self._config.default_access_mode
#     135 try:
# --> 136     super()._connect(
#     137         access_mode, auth=self._config.auth, **acquire_kwargs
#     138     )
#     139 except asyncio.CancelledError:
#     140     self._handle_cancellation(message="_connect")
#
# File ~/Works/graph-exp/.venv/lib/python3.12/site-packages/neo4j/_sync/work/workspace.py:199, in Workspace._connect(self, access_mode, auth, **acquire_kwargs)
#     189 acquire_kwargs_ = {
#     190     "access_mode": access_mode,
#     191     "timeout": acquisition_timeout,
#    (...)    196     "database_callback": self._make_db_resolution_callback(),
#     197 }
#     198 acquire_kwargs_.update(acquire_kwargs)
# --> 199 self._connection = self._pool.acquire(**acquire_kwargs_)
#     200 if (
#     201     target_db.guessed
#     202     and not self._pinned_database
#    (...)    206     # support SSR.
#     207     # => we need to fall back to explicit home database resolution
#     208     log.debug(
#     209         "[#0000]  _: <WORKSPACE> detected ssr support race; "
#     210         "falling back to explicit home database resolution",
#     211     )
#
# File ~/Works/graph-exp/.venv/lib/python3.12/site-packages/neo4j/_sync/io/_pool.py:676, in BoltPool.acquire(self, access_mode, timeout, database, bookmarks, auth, liveness_check_timeout, unprepared, database_callback)
#     669 log.debug(
#     670     "[#0000]  _: <POOL> acquire direct connection, "
#     671     "access_mode=%r, database=%r",
#     672     access_mode,
#     673     database,
#     674 )
#     675 deadline = Deadline.from_timeout_or_deadline(timeout)
# --> 676 return self._acquire(
#     677     self.address, auth, deadline, liveness_check_timeout, unprepared
#     678 )
#
# File ~/Works/graph-exp/.venv/lib/python3.12/site-packages/neo4j/_sync/io/_pool.py:417, in IOPool._acquire(self, address, auth, deadline, liveness_check_timeout, unprepared)
#     412             raise ClientError(
#     413                 "failed to obtain a connection from the pool within "
#     414                 f"{deadline.original_timeout!r}s (timeout)"
#     415             )
#     416 log.debug("[#0000]  _: <POOL> trying to hand out new connection")
# --> 417 return connection_creator()
#
# File ~/Works/graph-exp/.venv/lib/python3.12/site-packages/neo4j/_sync/io/_pool.py:230, in IOPool._acquire_new_later.<locals>.connection_creator()
#     228 try:
#     229     try:
# --> 230         connection = self.opener(
#     231             address, auth or self.pool_config.auth, deadline
#     232         )
#     233     except ServiceUnavailable:
#     234         self.deactivate(address)
#
# File ~/Works/graph-exp/.venv/lib/python3.12/site-packages/neo4j/_sync/io/_pool.py:637, in BoltPool.open.<locals>.opener(addr, auth_manager, deadline)
#     636 def opener(addr, auth_manager, deadline):
# --> 637     return Bolt.open(
#     638         addr,
#     639         auth_manager=auth_manager,
#     640         deadline=deadline,
#     641         routing_context=None,
#     642         pool_config=pool_config,
#     643     )
#
# File ~/Works/graph-exp/.venv/lib/python3.12/site-packages/neo4j/_sync/io/_bolt.py:368, in Bolt.open(cls, address, auth_manager, deadline, routing_context, pool_config)
#     365 if deadline is None:
#     366     deadline = Deadline(None)
# --> 368 s, protocol_version, handshake, data = BoltSocket.connect(
#     369     address,
#     370     tcp_timeout=pool_config.connection_timeout,
#     371     deadline=deadline,
#     372     custom_resolver=pool_config.resolver,
#     373     ssl_context=pool_config.get_ssl_context(),
#     374     keep_alive=pool_config.keep_alive,
#     375 )
#     377 pool_config.protocol_version = protocol_version
#     378 protocol_handlers = Bolt.protocol_handlers
#
# File ~/Works/graph-exp/.venv/lib/python3.12/site-packages/neo4j/_sync/io/_bolt_socket.py:376, in BoltSocket.connect(cls, address, tcp_timeout, deadline, custom_resolver, ssl_context, keep_alive)
#     374 else:
#     375     error_strs = "\n".join(map(str, errors))
# --> 376     raise ServiceUnavailable(
#     377         f"Couldn't connect to {address} (resolved to {address_strs}):"
#     378         f"\n{error_strs}"
#     379     ) from errors[0]
#
# ServiceUnavailable: Couldn't connect to localhost:7687 (resolved to ('127.0.0.1:7687',)):
# Failed to read four byte Bolt handshake response from server ResolvedIPv4Address(('127.0.0.1', 7687)) (deadline Deadline(timeout=60.0))
